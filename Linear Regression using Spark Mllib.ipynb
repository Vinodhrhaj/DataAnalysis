# %% [markdown]
# # Linear Regression using Spark Mllib

# %% [markdown]
# Data Preparation

# %% [markdown]
# Import the necessary Pyspark Sql functions necessary. If you are using row, make sure you are using Spark version 1.4 above.

# %%
from __future__ import print_function

from pyspark.ml.regression import LinearRegression

from pyspark.sql import SparkSession
from pyspark.ml.linalg import Vectors

# %% [markdown]
# Read the dataset as an rdd and store it as rdd1. Make sure your dataset has a numeric prediction variable

# %%
if __name__ == "__main__":

    # Create a SparkSession (Note, the config section is only for Windows!)
    spark = SparkSession.builder.config("spark.sql.warehouse.dir", "file:///C:/temp").appName("LinearRegression").getOrCreate()

# %%
    # Load up our data and convert it to the format MLLib expects.
    inputLines = spark.sparkContext.textFile('regression.txt')
    data = inputLines.map(lambda x: x.split(",")).map(lambda x: (float(x[0]), Vectors.dense(float(x[1]))))

# %%
    # Convert this RDD to a DataFrame
    colNames = ["label", "features"]
    df = data.toDF(colNames)

    # Note, there are lots of cases where you can avoid going from an RDD to a DataFrame.
    # Perhaps you're importing data from a real database. Or you are using structured streaming
    # to get your data.

# %%
    # Let's split our data into training data and testing data
    trainTest = df.randomSplit([0.5, 0.5])
    trainingDF = trainTest[0]
    testDF = trainTest[1]

    # Now create our linear regression model
    lir = LinearRegression(maxIter=10, regParam=0.3, elasticNetParam=0.8)

    # Train the model using our training data
    model = lir.fit(trainingDF)
    
    import  findspark
findspark.init()
import pyspark as ps
import warnings
from pyspark.sql import SQLContext

    # Now see if we can predict values in our test data.
    # Generate predictions using our linear regression model for all features in our
    # test dataframe:
    fullPredictions = model.transform(testDF).cache()

    # Extract the predictions and the "known" correct labels.
    predictions = fullPredictions.select("prediction").rdd.map(lambda x: x[0])
    labels = fullPredictions.select("label").rdd.map(lambda x: x[0])

    # Zip them together
    predictionAndLabel = predictions.zip(labels).collect()

    # Print out the predicted and actual values for each point
    for prediction in predictionAndLabel:
      print(prediction)
# Out:
# (-2.65764264664974, -3.74)
# (-1.5482369599878176, -2.17)
# (-1.3917823118688286, -2.09)
# (-1.398893886783328, -1.94)
# (-1.3348897125528325, -1.88)
# (-1.2211045139208405, -1.79)
# (-1.171323489519344, -1.77)
# (-1.0290919912293541, -1.67)
# (-1.1499887647758456, -1.65)
# (-1.1499887647758456, -1.6)
# (-1.1428771898613461, -1.59)
# (-1.100207740374349, -1.57)
# (-1.1855466393483431, -1.53)
# (-1.0290919912293541, -1.47)
# (-0.9295299424263611, -1.4)
# (-0.9935341166568565, -1.36)
# (-0.915306792597362, -1.34)
# (-0.829967893623368, -1.3)
# (-1.0362035661438536, -1.29)
# (-0.8370794685378675, -1.27)
# (-0.8228563187088684, -1.26)
# (-0.8441910434523671, -1.25)
# (-0.9295299424263611, -1.25)
# (-0.7659637193928726, -1.24)
# (-0.8441910434523671, -1.22)
# (-0.8441910434523671, -1.2)
# (-0.872637343110365, -1.17)
# (-0.8797489180248645, -1.17)
# (-0.8086331688798695, -1.14)
# (-0.8655257681958656, -1.11)
# (-0.744628994649374, -1.09)
# (-0.829967893623368, -1.09)
# (-0.7872984441363711, -1.08)
# (-0.701959545162377, -1.05)
# (-0.5952859214448845, -1.03)
# (0.05186739577457007, 0.08)
# (0.002086371373073567, 0.08)
# (-0.019248353370424937, 0.08)
# (0.08742527034706757, 0.09)
# (0.03764424594557107, 0.09)
# (0.02342109611657207, 0.09)
# (0.002086371373073567, 0.09)
# (0.07320212051806857, 0.11)
# (-0.026359928284924436, 0.11)
# (0.08742527034706757, 0.13)
# (0.10875999509056608, 0.14)
# (0.08742527034706757, 0.14)
# (0.1940988940645601, 0.15)
# (0.15142944457756308, 0.15)
# (0.15142944457756308, 0.16)
# (0.08031369543256808, 0.17)
# (0.07320212051806857, 0.17)
# (0.13720629474856408, 0.18)
# (0.1158715700050656, 0.18)
# (0.07320212051806857, 0.18)
# (0.22965676863705758, 0.22)
# (0.2225451937225581, 0.23)
# (0.20121046897905961, 0.24)
# (0.17987574423556107, 0.25)
# (0.13720629474856408, 0.25)
# (0.07320212051806857, 0.25)
# (0.2083220438935591, 0.26)
# (0.1940988940645601, 0.26)
# (0.15142944457756308, 0.26)
# (0.2936609428675531, 0.29)
# (0.1585410194920626, 0.29)
# (0.12298314491956508, 0.29)
# (0.32921881744005066, 0.3)
# (0.21543361880805859, 0.3)
# (0.2225451937225581, 0.32)
# (0.1869873191500606, 0.33)
# (0.33633039235455015, 0.39)
# (0.32921881744005066, 0.4)
# (0.28654936795305364, 0.4)
# (0.2652146432095551, 0.4)
# (0.3007725177820526, 0.41)
# (0.31499566761105163, 0.42)
# (0.34344196726904963, 0.43)
# (0.2723262181240546, 0.44)
# (0.30788409269655215, 0.45)
# (0.3007725177820526, 0.45)
# (0.3221072425255511, 0.46)
# (0.2723262181240546, 0.49)
# (0.45011559098654214, 0.5)
# (0.40744614149954517, 0.53)
# (0.5212313401315372, 0.54)
# (0.30788409269655215, 0.54)
# (0.4927850404735392, 0.55)
# (0.4785618906445402, 0.58)
# (0.44300401607204265, 0.58)
# (0.43589244115754316, 0.59)
# (0.49989661538803865, 0.61)
# (0.3505535421835491, 0.61)
# (0.40744614149954517, 0.63)
# (0.45011559098654214, 0.64)
# (0.5141197652170376, 0.66)
# (0.46433874081554116, 0.68)
# (0.6421281136780287, 0.7)
# (0.4003345665850457, 0.7)
# (0.5639007896185342, 0.73)
# (0.4785618906445402, 0.74)
# (0.43589244115754316, 0.75)
# (0.5567892147040346, 0.76)
# (0.5710123645330337, 0.78)
# (0.5212313401315372, 0.79)
# (0.6492396885925282, 0.8)
# (0.6919091380795251, 0.82)
# (0.5994586641910317, 0.82)
# (0.5923470892765321, 0.84)
# (0.5283429150460367, 0.84)
# (0.5710123645330337, 0.85)
# (0.5567892147040346, 0.85)
# (0.6421281136780287, 0.86)
# (0.6350165387635291, 0.87)
# (0.4572271659010417, 0.89)
# (0.6705744133360267, 0.9)
# (0.6279049638490297, 0.9)
# (0.7274670126520227, 0.95)
# (0.6634628384215272, 0.97)
# (0.6492396885925282, 0.97)
# (0.6563512635070277, 0.98)
# (0.6776859882505262, 0.99)
# (0.6990207129940247, 1.0)
# (0.6492396885925282, 1.03)
# (0.8270290614550156, 1.05)
# (-0.7304058448203751, -0.82)
# (-0.6664016705898795, -0.81)
# (-0.559728046872387, -0.8)
# (-0.573951196701386, -0.79)
# (-0.6379553709318815, -0.79)
# (-0.65929009567538, -0.77)
# (-0.6095090712738835, -0.76)
# (-0.545504897043388, -0.75)
# (-0.3748270990954, -0.73)
# (-0.51705859738539, -0.73)
# (-0.4672775729838935, -0.72)
# (-0.47438914789839304, -0.71)
# (-0.5383933221288885, -0.7)
# (-0.5099470224708905, -0.65)
# (-0.43171969841139596, -0.64)
# (-0.41038497366789745, -0.62)
# (-0.417496548582397, -0.62)
# (-0.4388312733258955, -0.61)
# (-0.3677155241809005, -0.6)
# (-0.417496548582397, -0.59)
# (-0.5383933221288885, -0.58)
# (-0.28948820012140597, -0.57)
# (-0.28237662520690643, -0.56)
# (-0.445942848240395, -0.56)
# (-0.33215764960840294, -0.55)
# (-0.48150072281289247, -0.55)
# (-0.27526505029240694, -0.54)
# (-0.3392692245229025, -0.54)
# (-0.4388312733258955, -0.54)
# (-0.3961618238388984, -0.48)
# (-0.48150072281289247, -0.48)
# (-0.29659977503590546, -0.44)
# (-0.34638079943740196, -0.44)
# (-0.24681875063440897, -0.42)
# (-0.31793449977940397, -0.42)
# (-0.1828145764039135, -0.41)
# (-0.21837245097641098, -0.41)
# (-0.28237662520690643, -0.41)
# (-0.14725670183141595, -0.4)
# (-0.3108229248649045, -0.39)
# (-0.25393032554890843, -0.37)
# (-0.30371134995040494, -0.37)
# (-0.4246081234968965, -0.37)
# (-0.28948820012140597, -0.35)
# (-0.21837245097641098, -0.34)
# (-0.16859142657491447, -0.33)
# (-0.11881040217341796, -0.3)
# (-0.18992615131841298, -0.3)
# (-0.27526505029240694, -0.3)
# (-0.28237662520690643, -0.3)
# (-0.1828145764039135, -0.28)
# (-0.2254840258909105, -0.28)
# (-0.24681875063440897, -0.28)
# (-0.17570300148941398, -0.25)
# (-0.033471503199423935, -0.24)
# (-0.21837245097641098, -0.21)
# (-0.2254840258909105, -0.21)
# (-0.20414930114741198, -0.2)
# (-0.10458725234441896, -0.19)
# (0.016309521202072567, -0.18)
# (-0.05480622794292244, -0.18)
# (-0.06191780285742194, -0.18)
# (-0.11881040217341796, -0.15)
# (-0.19703772623291246, -0.14)
# (-0.1828145764039135, -0.12)
# (-0.019248353370424937, -0.11)
# (-0.09747567742991944, -0.11)
# (-0.005025203541425934, -0.1)
# (0.002086371373073567, -0.09)
# (-0.005025203541425934, -0.07)
# (-0.04058307811392344, -0.07)
# (-0.005025203541425934, -0.05)
# (-0.15436827674591547, -0.04)
# (0.09453684526156708, -0.02)
# (0.016309521202072567, -0.02)
# (0.08031369543256808, -0.0)
# (0.05186739577457007, -0.0)
# (0.10875999509056608, 0.0)
# (0.1158715700050656, 0.01)
# (0.12298314491956508, 0.05)
# (0.05186739577457007, 0.05)
# (0.1443178696630636, 0.08)
# (0.05897897068906958, 0.1)
# (0.03764424594557107, 0.11)
# (0.002086371373073567, 0.12)
# (0.20121046897905961, 0.15)
# (0.1940988940645601, 0.15)
# (0.16565259440656208, 0.19)
# (0.07320212051806857, 0.19)
# (0.13720629474856408, 0.21)
# (0.2367683435515571, 0.22)
# (0.16565259440656208, 0.24)
# (0.17987574423556107, 0.25)
# (0.1443178696630636, 0.25)
# (0.22965676863705758, 0.26)
# (0.20121046897905961, 0.29)
# (0.1727641693210616, 0.29)
# (0.1940988940645601, 0.3)
# (0.22965676863705758, 0.31)
# (0.22965676863705758, 0.31)
# (0.27943779303855415, 0.32)
# (0.15142944457756308, 0.32)
# (0.15142944457756308, 0.34)
# (0.37899984184154717, 0.38)
# (0.33633039235455015, 0.38)
# (0.37188826692704763, 0.4)
# (0.33633039235455015, 0.4)
# (0.4003345665850457, 0.41)
# (0.33633039235455015, 0.42)
# (0.2652146432095551, 0.42)
# (0.27943779303855415, 0.44)
# (0.47145031573004065, 0.45)
# (0.4572271659010417, 0.45)
# (0.37899984184154717, 0.45)
# (0.34344196726904963, 0.45)
# (0.22965676863705758, 0.45)
# (0.25099149338055615, 0.47)
# (0.42166929132854414, 0.48)
# (0.32921881744005066, 0.49)
# (0.27943779303855415, 0.51)
# (0.3221072425255511, 0.53)
# (0.3505535421835491, 0.55)
# (0.3221072425255511, 0.55)
# (0.42166929132854414, 0.56)
# (0.28654936795305364, 0.56)
# (0.37188826692704763, 0.58)
# (0.49989661538803865, 0.6)
# (0.5425660648750357, 0.61)
# (0.5070081903025381, 0.63)
# (0.47145031573004065, 0.63)
# (0.3505535421835491, 0.64)
# (0.5781239394475332, 0.67)
# (0.6065702391055312, 0.68)
# (0.4572271659010417, 0.68)
# (0.44300401607204265, 0.68)
# (0.6279049638490297, 0.69)
# (0.5852355143620327, 0.69)
# (0.5781239394475332, 0.73)
# (0.4927850404735392, 0.73)
# (0.43589244115754316, 0.74)
# (0.6136818140200306, 0.75)
# (0.5781239394475332, 0.78)
# (0.5852355143620327, 0.81)
# (0.5283429150460367, 0.82)
# (0.5354544899605361, 0.85)
# (0.5781239394475332, 0.88)
# (0.6492396885925282, 0.9)
# (0.6919091380795251, 0.93)
# (0.6705744133360267, 0.93)
# (0.7559133123100207, 0.95)
# (0.6207933889345302, 0.95)
# (0.7559133123100207, 0.96)
# (0.6065702391055312, 0.97)
# (0.8270290614550156, 0.98)
# (0.7630248872245202, 0.98)
# (0.6350165387635291, 0.99)
# (0.7772480370535193, 1.0)
# (0.7772480370535193, 1.05)
# (0.7985827617970178, 1.09)
# (0.7559133123100207, 1.09)
# (0.9621489848305063, 1.13)
# (0.8981448106000107, 1.13)
# (0.7772480370535193, 1.13)
# (0.7630248872245202, 1.14)
# (0.8270290614550156, 1.16)
# (0.7559133123100207, 1.16)
# (1.004818434317503, 1.17)
# (0.8554753611130137, 1.19)
# (0.8625869360275132, 1.2)
# (0.9550374099160068, 1.25)
# (0.9408142600870077, 1.26)
# (0.8625869360275132, 1.27)
# (0.8625869360275132, 1.28)
# (1.0261531590610018, 1.29)
# (0.9408142600870077, 1.34)
# (0.9692605597450058, 1.35)
# (0.9550374099160068, 1.38)
# (1.0545994587189997, 1.41)
# (1.1186036329494953, 1.5)
# (1.0403763088900007, 1.53)
# (1.1470499326074932, 1.54)
# (1.1470499326074932, 1.55)
# (1.1328267827784944, 1.59)
# (1.1257152078639947, 1.65)
# (1.1897193820944902, 1.69)
# (1.2110541068379888, 1.8)
# (1.2608351312394852, 1.82)
# (1.2963930058119828, 1.85)
# (1.3390624552989798, 1.86)
# (1.2252772566669878, 1.93)
# (1.4741823786744703, 1.98)
# (1.9222115982879389, 2.62)
# (2.0715546714924282, 2.71)
# (2.000438922347433, 2.76)

# %% [markdown]
# We can use take() to have a look at our data. A take(5) shows the first 5 rows from our csv file

# %%
rdd1.take(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-fa42ad3b3076> in <module>()
# ----> 1 rdd1.take(5)
#
# NameError: name 'rdd1' is not defined

# %%
rdd1 = rdd1.map(lambda line: line.split(","))

# %%
rdd1.take(2)

# %% [markdown]
# Remove the headers

# %%
header = rdd1.first()
rdd1 = rdd1. filter(lambda line:line != header)

# %%
rdd1.take(2)

# %% [markdown]
# Convert to a DataFrame

# %%
df1 = rdd1.map(lambda line:Row(Price = line[0], Age =line[1],KM =line[2], FuelType =line[3],HP =line[4], MetColor =line[5], Automatic =line[6], CC =line[7],Doors = line [8],Weight = line [9])).toDF()

# %%
df1.show(5)

# %% [markdown]
# View as a Pandas DataFrame- All these steps help understand the data better

# %%
df1.toPandas().head()

# %%
df1.describe(['Price','CC','Age','KM']).show()

# %% [markdown]
# # Linear Regression with Spark mllib

# %%
import pyspark.mllib
import pyspark.mllib.regression
from pyspark.mllib.regression import LabeledPoint
from pyspark.sql.functions import *

# %% [markdown]
# Select only the columns that you consider important to predict the output variable. You can use describe to show the summary stats

# %%
df1=df1.select('Price','CC','Age','KM')
df1.describe(['Price','CC','Age','KM']).show()

# %%
df1.take(2)

# %%
type(df1)

# %%
df1.printSchema()

# %% [markdown]
# # Labeled Points

# %% [markdown]
# An important thing to note about mllib is that it requires our features to be expressed with LabeledPoints. Use map on df to return as an RDD of LabledPoints

# %%
temp = df1.map(lambda line: LabeledPoint(line[0],[line[1:]]))

# %%
temp.take(5)

# %% [markdown]
# Use the StandardScaler in Spark to scale the data

# %%
from pyspark.mllib.util import MLUtils
from pyspark.mllib.linalg import Vectors
from pyspark.mllib.feature import StandardScaler

# %% [markdown]
# Use an RDD to scale the data

# %%
features = df1.map(lambda row: row[1:])

# %%
features.take(1)

# %%
standardizer = StandardScaler()
model = standardizer.fit(features)
features_transform = model.transform(features)

# %% [markdown]
# # The scaled features :

# %%
features_transform.take(5)

# %% [markdown]
# # Add labels together with the features

# %%
labels = df1.map(lambda row: row[0])
labels.take(5)

# %%
transformedData = labels.zip(features_transform)
transformedData.take(5)

# %%
transformedData = transformedData.map(lambda row : LabeledPoint(row[0],row[1]))
transformedData.take(5)

# %% [markdown]
# # Build the Model

# %%
trainingData, testingData = transformedData.randomSplit([.8,.2],seed=1234)

# %%
from pyspark.mllib.regression import LinearRegressionWithSGD

# %%
linearModel = LinearRegressionWithSGD.train(trainingData,1000,.2)

# %%
linearModel.weights

# %%
testingData.take(10)

# %%
linearModel.predict([8.5478,1.5054,0.8591])
